# %%
import numpy as np
data = np.random.randn(1000)
data.mean(), data.std()
# Out:
# (np.float64(-0.05173562924112544), np.float64(0.9997772377989562))

# %%
from random import randint

# %timeit [randint(0,10) for i in range(100000)]
# Out:
# 84.6 ms ± 3.52 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
rng = np.random.default_rng()
# %timeit rng.integers(low=0, high=100001, size=(3, 3))
# Out:
# 51.4 μs ± 15.1 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
